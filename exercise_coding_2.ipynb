# %% [markdown]
# ## **Welcome to the small workshop on "How to optimise your prompt on [insert-your-favorite-genAI-chatbot]** :)

# %%
# Test that code runs - push "Arrow" or click on code fragment and click "Ctrl + Enter"
a = "Yeeeah, the code runs!!!"
print(a)
# Out:
# Yeeeah, the code runs!!!

# %% [markdown]
# ## Exercise 1: Prompt a genAI to perform data cleaning and pre-processing.

# %%
# Example dataset
import pandas as pd
import numpy as np

np.random.seed(42)
dates = ['2023-01-01', '01/02/2023', '2023/03/01', 'March 4, 2023', '2023.05.01', '2023/06/15', '15-07-2023', None]
revenues = ['1000', '2000', 'N/A', np.nan, '1500', '2500', 'error', '3000']
customer_ids = ['C001', 'C002', 'C003', 'C004', 'C005', 'C002', 'C006', None]

df = pd.DataFrame({
    'Date': np.random.choice(dates, 500),
    'Revenue': np.random.choice(revenues, 500),
    'Customer_ID': np.random.choice(customer_ids, 500)
})

print("\n🔍 Sample messy dataset:")
df.head()
# Out:
# 🔍 Sample messy dataset:
#               Date Revenue Customer_ID
# 0       15-07-2023   error        C002
# 1    March 4, 2023    1500        C006
# 2       2023.05.01    1500        C001
# 3       15-07-2023    3000        C001
# 4       2023/03/01   error        C001
# ..             ...     ...         ...
# 495     15-07-2023    1500        C005
# 496     2023/03/01    1000        None
# 497  March 4, 2023     nan        None
# 498     2023-01-01    3000        C003
# 499  March 4, 2023     N/A        C006
#
# [500 rows x 3 columns]

# %%
 # Place for your code (You can click on "+ Code" to create new cells)

# %% [markdown]
#  ## Exercise 2: Visualize results in a "paper-ready" way

# %%
# Example dataset
from datetime import timedelta, datetime

sales_dates = pd.date_range(start='2023-01-01', periods=365, freq='D')
sales = np.random.randint(500, 10000, size=365)

sales_df = pd.DataFrame({
    'Date': sales_dates,
    'Sales': sales
})

print("\n📈 Sample sales data:")
sales_df.head()
# Out:
# 📈 Sample sales data:
#           Date  Sales
# 0   2023-01-01   9505
# 1   2023-01-02   2532
# 2   2023-01-03   8936
# 3   2023-01-04    771
# 4   2023-01-05   4011
# ..         ...    ...
# 360 2023-12-27   3716
# 361 2023-12-28   8719
# 362 2023-12-29   2613
# 363 2023-12-30   9944
# 364 2023-12-31   4856
#
# [365 rows x 2 columns]

# %%
 # Place for your code (You can click on "+ Code" to create new cells)

# %% [markdown]
# ## Exercise 3: transform the following code from R to Python using genAI

# %% [markdown]
# ### (Expected Results can checked on the Github repository)

# %% [markdown]
# ```
# # Load necessary libraries
# library(ggplot2)
# library(dplyr)
#
# # 1. Simulate data
# set.seed(42)
# df <- data.frame(
#   group = rep(c("Control", "Treatment_A", "Treatment_B"), each = 40),
#   value = c(rnorm(40, mean = 5, sd = 1),
#             rnorm(40, mean = 6, sd = 1.2),
#             rnorm(40, mean = 7, sd = 1.5))
# )
#
# # 2. Preprocess: Ensure factor type
# df$group <- as.factor(df$group)
#
# # 3. Statistical Tests
# # Normality check per group
# by(df$value, df$group, shapiro.test)
#
# # Bartlett's test for homogeneity of variances
# bartlett.test(value ~ group, data = df)
#
# # Kruskal-Wallis test (non-parametric ANOVA alternative)
# kruskal <- kruskal.test(value ~ group, data = df)
# print(kruskal)
#
# # Pairwise Wilcoxon test with Bonferroni correction
# pairwise <- pairwise.wilcox.test(df$value, df$group, p.adjust.method = "bonferroni")
# print(pairwise)
#
# # 4. Compute summary statistics for plotting
# summary_df <- df %>%
#   group_by(group) %>%
#   summarise(
#     median = median(value),
#     q1 = quantile(value, 0.25),
#     q3 = quantile(value, 0.75)
#   )
#
# # 5. Visualization
# p <- ggplot(df, aes(x = group, y = value, fill = group)) +
#   geom_boxplot(alpha = 0.6, outlier.shape = NA) +
#   geom_jitter(width = 0.2, alpha = 0.4, size = 1.2) +
#   stat_summary(fun = median, geom = "point", shape = 21, size = 3, fill = "black") +
#   labs(
#     title = "Group Comparison: Kruskal-Wallis Test",
#     subtitle = paste("p =", signif(kruskal$p.value, 3)),
#     x = "Group", y = "Response"
#   ) +
#   theme_minimal(base_size = 14) +
#   theme(legend.position = "none")
#
# # Optional: Add asterisks manually based on post-hoc p-values
# # Example: suppose significant p < 0.05 for A vs B and Control vs B
# p + annotate("text", x = 1.5, y = 10.5, label = "*", size = 6) +
#     annotate("text", x = 2.5, y = 11.0, label = "**", size = 6)
# ```

# %%
# Place for your code (You can click on "+ Code" to create new cells)

# %% [markdown]
# ## Exercise 4 - create an interactive Shiny-style web application using genAI

# %%
# Example dataset

np.random.seed(123)
regions = ['North', 'South', 'East', 'West']
product_lines = ['A', 'B', 'C']
dates = pd.date_range(start='2024-01-01', periods=180)

data = pd.DataFrame({
    'Date': np.random.choice(dates, 1000),
    'Region': np.random.choice(regions, 1000),
    'Product': np.random.choice(product_lines, 1000),
    'Sales': np.random.randint(100, 5000, size=1000)
})

print("\n📅 Dummy dataset for app:")
data.head()


# Your Task:
# Write a detailed prompt to generate an interactive app that:
# - Lets the user filter by Region and Product
# - Displays a line chart of daily sales
# - Shows total sales in a summary box
# - Has a clean layout and intuitive controls

# %%
# Place for your code (You can click on "+ Code" to create new cells)
