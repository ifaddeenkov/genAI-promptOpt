# %% [markdown]
# **Welcome to the small workshop on "How to optimise your prompt on <insert-your-favorite-genAI-chatbot>** :)
#
# # 📊 Prompt-Driven Data Processing with GenAI
# ## Seminar: Prompt Optimization for GenAI Chatbots
#
# In this notebook, you'll:
# - Use a GenAI chatbot to guide a data-cleaning workflow
# - Visualize results
# - Build a simple interactive web app using Gradio
#
# 🔧 Requirements: None! This runs in Google Colab.

# %%
# Test that code runs - push "Arrow" or click on code fragment and click "Ctrl + Enter"
a = "Yeeeah, the code runs!!!"
print(a)
# Out:
# Yeeeah, the code runs!!!

# %% [markdown]
# ###🧠 Assignment 1: Prompt a GenAI (like ChatGPT) to Guide Data Cleaning

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
myExampleData = pd.DataFrame({
    "Name": [f"Item_{i}" for i in range(1, 101)],
    "Category": np.random.choice(["A", "B", "C"], 100),
    "Value": np.random.randn(100) * 20 + 100,
    "OutlierFlag": np.random.choice([True, False], 100, p=[0.1, 0.9])
})

myExampleData.head()
# Out:
#      Name Category       Value  OutlierFlag
# 0  Item_1        C  111.642456        False
# 1  Item_2        A  117.754969         True
# 2  Item_3        C  117.886647        False
# 3  Item_4        C  115.099956        False
# 4  Item_5        A   95.856682        False

# %% [markdown]
# #### Your code
